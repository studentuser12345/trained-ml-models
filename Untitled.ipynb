# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
label=['a','b','c','d','e','f','g','h','i','j']

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

# %%
df=pd.DataFrame(data,index=label)

# %%
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
import tensorflow
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

# %%
data=pd.read_csv(r"C:\Users\PRAJWAL\Downloads\student_mat_2173a47420.csv",sep=";")

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
data.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
data.shape
# Out:
# (395, 33)

# %%
data.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.boxplot(column=["age","freetime","famrel"])
plt.show()

# %%
sns.heatmap(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sns.heatmap(data)
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...

# %%
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

predict = "G3"

X = np.array(data.drop([predict], axis=1))
y = np.array(data[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
y_predit=model.predict(x_train)

# %%
print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
new_prediction = model.predict([[6]])

print("Predicted score:", new_prediction)
# Out:
# Coefficient: [ 0.14974465  0.98478434 -0.13222618 -0.15687618  0.03270853]
# Intercept: -1.610701307777326
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 3
#       1 print("Coefficient:", model.coef_)
#       2 print("Intercept:", model.intercept_)
# ----> 3 new_prediction = model.predict([[6]])
#       5 print("Predicted score:", new_prediction)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
# ...

# %%
acc = model.score(x_test, y_test)
print(acc)

print('Coefficient: \n', model.coef_)
print('Intercept: \n', model.intercept_)

predictions = model.predict(x_test)

for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])
    print(
# Out:
# 0.8118504085757926
# Coefficient:
#  [ 0.14974465  0.98478434 -0.13222618 -0.15687618  0.03270853]
# Intercept:
#  -1.610701307777326
# 11.114203686179478 [12 11  2  0 11] 11
# 18.24687876197142 [16 18  2  0  0] 18
# 13.990733653801502 [13 14  1  0  0] 14
# 12.506032671433134 [11 13  4  0  6] 14
# 12.741496950965045 [13 13  3  0  0] 13
# 7.717283220454277 [ 9  8  2  1 16] 7
# 4.189993658385608 [ 5  5  2  0 12] 5
# 9.619880828136019 [11 10  2  0  0] 10
# -0.5274518282282894 [9 0 2 0 0] 0
# 15.588294607813804 [16 15  1  0  5] 16
# 12.75901541703255 [14 13  4  0  0] 14
# 5.9329309908848336 [7 7 4 0 4] 6
# 13.1543019196869 [14 13  2  0  4] 13
# 12.031551918966166 [15 12  2  1  0] 12
# 10.155431214954609 [ 8 11  2  0  0] 11
# 10.845403885640852 [13 11  2  1  3] 11
# 6.863333020272169 [ 9  7  2  1 20] 8
# 12.895579692640135 [12 13  1  1  6] 14
# 16.192982508684317 [15 16  2  0  2] 16
# -0.8515911230391556 [7 0 1 1 0] 0
# 10.340212796720193 [11 11  4  0  0] 11
# ...
